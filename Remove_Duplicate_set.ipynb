# %%
#Create
#numbers = [10, 20, 30, 20, 40, 10, 50, 30, 60]

#Without using loops

#Print the original list, Convert the list into a set, Observe which duplicates disappear, Convert the set back into a list

#Print the number of original elements, Print the number of unique elements, Create another example using duplicate student names.

#Explain why sets are useful when working with duplicate data.

# %%
numbers = [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
#Print the original list
print(numbers)
# Out:
# [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
# Convert the list into a set
unique_values = set(numbers)

# %%
# Observe which duplicates disappear
print(numbers)
print(set(numbers))
# Out:
# [10, 20, 30, 20, 40, 10, 50, 30, 60]
# {40, 10, 50, 20, 60, 30}

# %%
# Convert the set back into a list

original_elements = list(unique_values)

# %%
# Print the number of original elements
print(numbers)
# Out:
# [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
# Print the number of unique elements
print(unique_values)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
# Create another example using duplicate student names

students = {"ram", "bheem", "rahul", "ram", "rambo", "goel", "bheem"}

print(students)
# Out:
# {'rahul', 'ram', 'goel', 'rambo', 'bheem'}

# %%
# Explain why sets are useful when working with duplicate data.
# sets were used for remove duplicates so it will improve memory efficiency
# And as well as we have the ability for the faster lookups due to hashing mechnaism inside the set datastructure
# Due to this will o(1) time complexity
