# %%
#technologies = ("Python", "Java", "Python", "C++", "JavaScript", "Python")
#Perform the following

#Print the tuple, Print its type, Print the first item, Print the last item, Slice the tuple, Count "Python"
#Find the index of "C++", Find the tuple length, Convert the tuple into a list, Add "Go" after converting it into a list
#Convert it back into a tuple, 
#Explain why tuples are called immutable.

# %%
technologies = ("Python", "Java", "Python", "C++", "JavaScript", "Python")

# %%
#Print the tuple

print(technologies)
# Out:
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python')

# %%
#Print its type
type(technologies)
# Out:
# tuple

# %%
#Print the first item
technologies[0]
# Out:
# 'Python'

# %%
# Print the last item
technologies[-1]
# Out:
# 'Python'

# %%
# Slice the tuple
technologies[0:6:1]
# Out:
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python')

# %%
# Count "Python"
technologies.count("Python")
# Out:
# 3

# %%
#Find the index of "C++"
technologies.index("C++")
# Out:
# 3

# %%
# Find the tuple length
len(technologies)
# Out:
# 6

# %%
# Convert the tuple into a list
new_list = list(technologies)

# %%
type(new_list)
# Out:
# list

# %%
# Add "Go" after converting it into a list
new_list.append("Go")

# %%
print(new_list)
# Out:
# ['Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python', 'Go']

# %%
# Convert it back into a tuple,

new_technologies = tuple(new_list)

# %%
type(new_technologies)
# Out:
# tuple

# %%
#Explain why tuples are called immutable.

#lists were mutable
#tuples were immutable inorder to store the multiple secured values as similar to string in other programming languages to store single secured value
