# %%
#Create
#marks = [78, 85, 90, 67, 88, 92, 76]

#Perform the following operations

#Print the complete list, Print the first element, Print the last element, Print elements from index 2 to 5
#Find the number of elements, Find maximum marks, Find minimum marks, Find total marks,Sort marks in ascending order
#Sort marks in descending order,Add 95,Add [81, 84], Remove 67,Count how many times 90 occurs,Find the index of 88

# %%
marks = [78, 85, 90, 67, 88, 92, 76]

# %%
#Print the complete list
print(marks)
# Out:
# [78, 85, 90, 67, 88, 92, 76]

# %%
#Print the first element

print(marks[0])
# Out:
# 78

# %%
#Print the last element

print(marks[-1])
# Out:
# 76

# %%
#Print elements from index 2 to 5

print(marks[2:6])
# Out:
# [90, 67, 88, 92]

# %%
#Find the number of elements
len(marks)
# Out:
# 7

# %%
#Find maximum marks
max(marks)
# Out:
# 92

# %%
# Find minimum marks
min(marks)
# Out:
# 67

# %%
# Find total marks
sum(marks)
# Out:
# 576

# %%
# Sort marks in ascending order

marks.sort()
print(marks)
# Out:
# [67, 76, 78, 85, 88, 90, 92]

# %%
#Sort marks in descending order
marks.sort(reverse=True)
print(marks)
# Out:
# [92, 90, 88, 85, 78, 76, 67]

# %%
# Add 95
marks.append(95)
print(marks)
# Out:
# [92, 90, 88, 85, 78, 76, 67, 95]

# %%
# Add [81, 84]
marks.append([81, 84])

# %%
print(marks)
# Out:
# [92, 90, 88, 85, 78, 76, 67, 95, [81, 84]]

# %%
# Remove 67
marks.remove(67)

# %%
print(marks)
# Out:
# [92, 90, 88, 85, 78, 76, 95, [81, 84]]

# %%
#Count how many times 90 occurs
marks.count(90)
# Out:
# 1

# %%
#Find the index of 88
marks.index(88)
# Out:
# 2
