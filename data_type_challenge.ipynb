# %%
#Create at least 15 different variables containing examples of
#int, float, str, bool, list, tuple, set, dict
#Use type() to identify the data type of each variable.

#Also demonstrate basic type conversion such as
# examples : int("100"), float("45.67"), str(500), bool(1), list((1, 2, 3)), tuple([1, 2, 3]), set([1, 2, 2, 3])

#Explain what happens after every conversion.

# %%
name = "Ramachandar"
age = 26
height = 6.1
is_Confident = True
interests = ["coding", "learning", "implementing"]
future_scope = ("genai", "AgenticAi", "AIEngieer")
goals = {"data_scientist", "AI/ML engineer"}
details = {"qualification": "B.tech", "cgpa": 8.7, "year":2021}
scores = {"network-Analysis": "A", "Maths-1": "B", "VLSI":"A"}
hobbies = ["writing", "listening_music"]
cgpa = 8.7
year_of_passing = 2021
under_graduate = True
current_role = "Associate consultant"
future_role = "GENAI -engineer"

# %%
#Demonstration
#typecasting  from int to str
print(type(age))

type(age)
# Out:
# <class 'int'>
# int

# %%
new_age = str(age)

# %%
new_age
# Out:
# '26'

# %%
# int to bool  bool (0 and 1) 1==> True , 0==> False
bool(age)
# Out:
# True

# %%
ag2 = 0
bool(ag2)
# Out:
# False

# %%
#str to bool
bool(name)
# Out:
# True

# %%
name2 = ""

# %%
bool(name2)
# Out:
# False

# %%
#bool to int

int(is_Confident)
# Out:
# 1

# %%
# str  to int

int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 # str  to int
# ----> 3 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Ramachandar'

# %%
#float to int

type(height)

int(height) #6.2
# Out:
# 6

# %%
#int to float
float(age)
# Out:
# 26.0

# %%
#list to set conversion
type(interests)

set(interests)
# Out:
# {'coding', 'implementing', 'learning'}

# %%
#set to list 

type(goals)

list(goals)
# Out:
# ['AI/ML engineer', 'data_scientist']

# %%
#list to tuple
word_tup = tuple(interests)

print(word_tup)
# Out:
# ('coding', 'learning', 'implementing')

# %%
#tuple to list
new_future = list(future_scope)

print(new_future)
# Out:
# ['genai', 'AgenticAi', 'AIEngieer']

# %%
# tuple to dict 

dict(future_scope)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 # tuple to dict
# ----> 3 dict(future_scope)
#
# ValueError: dictionary update sequence element #0 has length 5; 2 is required

# %%
# list to dict 
dict(interests)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 # list to dict
# ----> 2 dict(interests)
#
# ValueError: dictionary update sequence element #0 has length 6; 2 is required

# %%
#dict to list
type(scores)

list(scores)
# Out:
# ['network-Analysis', 'Maths-1', 'VLSI']

# %%
##Explain what happens after every conversion.

#after typecasting the internal functionality of a specific datatype differs
