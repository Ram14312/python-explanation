# %%
#student = "python programming for data science"

#Perform operations to
#===========================
#Print the complete string, Print the first character, Print the last character, Print the first 6 characters, Print the last 7 characters
#Reverse the string using slicing, Convert it to uppercase, Convert it to lowercase, Convert it to title case, Count how many times "a" appears
#Find the position of "programming", Replace "data science" with "artificial intelligence", Split the string into individual words

# %%
student = "python programming for data science"

# %%
# Print the complete string
print(student)
# Out:
# python programming for data science

# %%
# Print the first character
print(student[0])
# Out:
# p

# %%
# Print the last character
print(student[-1])
# Out:
# e

# %%
# Print the first 6 characters
student[0:6:1]
# Out:
# 'python'

# %%
# Print the last 7 characters
student.index("science")
print(student[28:35])
# Out:
# science

# %%
# Reverse the string using slicing
student[::-1]
# Out:
# 'ecneics atad rof gnimmargorp nohtyp'

# %%
# Convert it to uppercase
student.upper()
# Out:
# 'PYTHON PROGRAMMING FOR DATA SCIENCE'

# %%
# Convert it to lowercase
student.lower()
# Out:
# 'python programming for data science'

# %%
# Convert it to title case
student.title()
# Out:
# 'Python Programming For Data Science'

# %%
#  Count how many times "a" appears
student.count("a")
# Out:
# 3

# %%
# Find the position of "programming"

student.index("programming")
# Out:
# 7

# %%
# Replace "data science" with "artificial intelligence"
student.replace("data science", "artificial intelligence")
# Out:
# 'python programming for artificial intelligence'

# %%
# Split the string into individual words
student.split()
# Out:
# ['python', 'programming', 'for', 'data', 'science']
