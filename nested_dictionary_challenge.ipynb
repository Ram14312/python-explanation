# %%
#employee = {"name": "Amit","department": "Engineering","skills": {"language": "Python", "database": "PostgreSQL","cloud": "AWS"},"salary": 80000}

#Without using loops

#Print employee name , Print department, Print complete skills dictionary, Print programming language, Print database,Print cloud technology
#Change "Python" to "Python + JavaScript", Change salary, Add "experience": 3, Add another skill under the skills dictionary
#Explain how nested dictionaries are accessed.

# %%
employee = {"name": "Amit","department": "Engineering","skills": {"language": "Python", "database": "PostgreSQL","cloud": "AWS"},"salary": 80000}

# %%
#Print employee name
print(employee['name'])
# Out:
# Amit

# %%
#Print department
print(employee['department'])
# Out:
# Engineering

# %%
#Print complete skills dictionary
print(employee['skills'])
# Out:
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}

# %%
#Print programming language
print(employee["skills"]["language"])
# Out:
# Python

# %%
#  Print database
print(employee["skills"]["database"])
# Out:
# PostgreSQL

# %%
# Print cloud technology
print(employee["skills"]["cloud"])
# Out:
# AWS

# %%
# Change "Python" to "Python + JavaScript"
employee["skills"]["language"] = "Python + JavaScript"

# %%
print(employee["skills"]['language'])
# Out:
# Python + JavaScript

# %%
# Change salary
employee["salary"] = 90000

# %%
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 90000}

# %%
# Add "experience": 3
employee['experience'] = 3

# %%
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 90000, 'experience': 3}

# %%
# Add another skill under the skills dictionary
employee["skills"]["UI"] = "Angular"

# %%
print(employee["skills"]["UI"])
# Out:
# Angular

# %%
# Explain how nested dictionaries are accessed.
# we can able to retrieve the values from nested loops  which looks similar to the the following  dict["key"]["key1_value"]
# key is the another dictionary
# key_1 is the key inside this nested dictinary which were required to retrieve
