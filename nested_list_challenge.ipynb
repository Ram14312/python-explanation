# %%
#What to build
 
#students = [["Rahul", 21, "Python"], ["Priya", 22, "Data Science"], ["Aman", 20, "Machine Learning"]]

#Without using loops
#Print the complete list, Print Rahul's name , Print Priya's age, Print Aman's course, Print the complete record of Priya, Change Rahul's course to "AI"
#Add another student record manually, Print the updated nested list, Explain how indexing works with nested lists.

# %%
students = [["Rahul", 21, "Python"], ["Priya", 22, "Data Science"], ["Aman", 20, "Machine Learning"]]

# %%
#Print the complete list
print(students)
# Out:
# [['Rahul', 21, 'Python'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning']]

# %%
#Print Rahul's name
print(students[0][0])
# Out:
# Rahul

# %%
# Print Priya's age
print(students[1][1])
# Out:
# 22

# %%
# Print Aman's course
print(students[2][2])
# Out:
# Machine Learning

# %%
# Print the complete record of Priya
print(students[1])
# Out:
# ['Priya', 22, 'Data Science']

# %%
# Change Rahul's course to "AI"
students[0][2] = "AI"

# %%
print(students[0])
# Out:
# ['Rahul', 21, 'AI']

# %%
# Add another student record manually
students.append(["ram", 26, "genai"])

# %%
# Print the updated nested list
print(students)
# Out:
# [['Rahul', 21, 'AI'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning'], ['ram', 26, 'genai'], ['ram', 26, 'genai']]

# %%
# Explain how indexing works with nested lists.
#first consider outer list based  on that each value is consider with an index
# so if we want to access a specific value inside the inner list then we need access the outer index first later we need access the inner index
# by this way we can able to access the values inside the nested lists
