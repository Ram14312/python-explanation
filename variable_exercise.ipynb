# %%
#Create Python variables to store the following details

#Your name,Age,City,College/company name,Current learning topic,Years of experience or study,Whether you like Python (True/False)
#Your expected salary after learning Python,Print every value.,Then print the data type of every variable using type().

#Concepts :
#Variables, string, integer, float, boolean, print(), type().

# %%
name = "Ramachandar"
Age = 26
City = "Tirupati"
company_name = "Infosys"
Current_learning_topic = "masteringGenAi"
years_of_experience = 4.11
love_python = True
expected_salary = 2000000

# %%
print(name)
print(Age)
print(City)
print(company_name)
print(Current_learning_topic)
print(years_of_experience)
print(love_python)
print(expected_salary)
# Out:
# Ramachandar
# 26
# Tirupati
# Infosys
# masteringGenAi
# 4.11
# True
# 2000000

# %%
type(name)
# Out:
# str

# %%
type(Age)
# Out:
# int

# %%
type(City)
# Out:
# str

# %%
type(company_name)
# Out:
# str

# %%
type(Current_learning_topic)
# Out:
# str

# %%
type(years_of_experience)
# Out:
# float

# %%
type(love_python)
# Out:
# bool

# %%
type(expected_salary)
# Out:
# int
